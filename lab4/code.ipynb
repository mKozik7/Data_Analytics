# %%
from cmdstanpy import CmdStanModel


import arviz as az
import numpy as np
import scipy.stats as stats

import matplotlib.pyplot as plt
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/rmcelreath/rethinking/Experimental/data"
data_path = f"{url}/Howell1.csv"
d = pd.read_csv(data_path, sep=';', header=0)
d=d[d.age>=18] #just adults 
d.head()
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041914  41.0     1
# 4  145.415  41.276872  51.0     0

# %%
model_ppc=CmdStanModel(stan_file='height_1_ppc.stan')

R = 1000
sim=model_ppc.sample(iter_sampling=R,
                     iter_warmup=0,
                     chains=1,
                     fixed_param=True,
                     seed=29042020,refresh=R)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
model_1_fit=CmdStanModel(stan_file=r'C:\Users\macie\OneDrive\Pulpit\All\Studia\AIR_2022\Data_analytics\Data_Analytics\lab4\height_1_fit.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
fit=model_1_fit.sample(data=dict(N=len(d), heights=d.height.values), seed=28052020)
mu = fit.stan_variable('mu')
sigma=fit.stan_variable('sigma')
height=fit.stan_variable('height')
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
fig, axes = plt.subplots(1, 2, figsize=(7, 4),sharex=True,sharey=True)
ax=axes[0]
ax.hist(d.height,bins=20,edgecolor='k',density=True)
ax.set_title('Observed height')
ax.set_yticks(())
ax2=axes[1]
ax2.hist(height,bins=20,edgecolor='k',density=True)
ax2.hist(d.height,bins=20,histtype='step',color='black',density=True)
ax2.set_title('Predicted height')
ax2.set_yticks(())
fig.tight_layout()
plt.show()

# %%
d["weight"].mean()
d.insert(3, "c_weight", (d["weight"]-d["weight"].mean()), True)
d.head()
# Out:
#     height     weight   age   c_weight  male
# 0  151.765  47.825606  63.0   2.835121     1
# 1  139.700  36.485807  63.0  -8.504679     0
# 2  136.525  31.864838  65.0 -13.125648     0
# 3  156.845  53.041914  41.0   8.051429     1
# 4  145.415  41.276872  51.0  -3.713614     0

# %%
model_ppc=CmdStanModel(stan_file=r'height_2a_pcc.stan')
R = 1000
data_sim={'N':50, 'weight':np.linspace(d.c_weight.min(),d.c_weight.max())}
sim=model_ppc.sample(data=data_sim, 
                     iter_sampling=R, 
                     iter_warmup=0, 
                     chains=1, 
                     refresh=R,
                     fixed_param=True,
                     seed=29042020)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
beta = sim.stan_variable('beta')
alpha = sim.stan_variable('alpha')
plt.plot(np.linspace(0,1000,1000),beta, linestyle='-')
plt.title('Beta')
plt.show()
plt.plot(np.linspace(0,1000,1000),alpha, linestyle = '-')
plt.title('Alpha')
plt.show()

# %%
model_ppc=CmdStanModel(stan_file=r'height_2b_pcc.stan')
# Out:
# INFO:cmdstanpy:compiling stan file C:\Users\macie\OneDrive\Pulpit\All\Studia\AIR_2022\Data_analytics\Data_Analytics\lab4\height_2b_pcc.stan to exe file C:\Users\macie\OneDrive\Pulpit\All\Studia\AIR_2022\Data_analytics\Data_Analytics\lab4\height_2b_pcc.exe
# INFO:cmdstanpy:compiled model executable: C:\Users\macie\OneDrive\Pulpit\All\Studia\AIR_2022\Data_analytics\Data_Analytics\lab4\height_2b_pcc.exe
# WARNING:cmdstanpy:Stan compiler has produced 2 warnings:
# WARNING:cmdstanpy:
# --- Translating Stan model to C++ code ---
# bin/stanc.exe  --o=C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2b_pcc.hpp C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2b_pcc.stan
# Warning in 'C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2b_pcc.stan', line 3, column 4: Declaration
#     of arrays by placing brackets after a variable name is deprecated and
#     will be removed in Stan 2.32.0. Instead use the array keyword before the
#     type. This can be changed automatically using the auto-format flag to
#     stanc
# Warning in 'C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2b_pcc.stan', line 10, column 3: Declaration
#     of arrays by placing brackets after a variable name is deprecated and
#     will be removed in Stan 2.32.0. Instead use the array keyword before the
#     type. This can be changed automatically using the auto-format flag to
#     stanc
#
# --- Compiling, linking C++ code ---
# g++ -std=c++1y -m64 -D_REENTRANT -Wall -Wno-unused-function -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-variable -Wno-sign-compare -Wno-unused-local-typedefs -Wno-int-in-bool-context -Wno-attributes -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.75.0 -I stan/lib/stan_math/lib/sundials_6.0.0/include -I stan/lib/stan_math/lib/sundials_6.0.0/src/sundials  -D_USE_MATH_DEFINES  -DBOOST_DISABLE_ASSERTS          -c  -x c++ -o C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2b_pcc.o C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2b_pcc.hpp
# g++ -std=c++1y -m64 -D_REENTRANT -Wall -Wno-unused-function -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-variable -Wno-sign-compare -Wno-unused-local-typedefs -Wno-int-in-bool-context -Wno-attributes -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.75.0 -I stan/lib/stan_math/lib/sundials_6.0.0/include -I stan/lib/stan_math/lib/sundials_6.0.0/src/sundials  -D_USE_MATH_DEFINES  -DBOOST_DISABLE_ASSERTS                -Wl,-L,"C:/Users/macie/anaconda3/envs/data/Library/bin/cmdstan/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"C:/Users/macie/anaconda3/envs/data/Library/bin/cmdstan/stan/lib/stan_math/lib/tbb"      C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2b_pcc.o src/cmdstan/main.o  -static-libgcc -static-libstdc++      -Wl,-L,"C:/Users/macie/anaconda3/envs/data/Library/bin/cmdstan/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"C:/Users/macie/anaconda3/envs/data/Library/bin/cmdstan/stan/lib/stan_math/lib/tbb"   stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_nvecserial.a stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_cvodes.a stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_idas.a stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_kinsol.a  stan/lib/stan_math/lib/tbb/tbb.dll -o C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2b_pcc.exe
# rm -f C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2b_pcc.o

# %%
sim=model_ppc.sample(data=data_sim, 
                     iter_sampling=R, 
                     iter_warmup=0, 
                     chains=1, 
                     refresh=R,
                     fixed_param=True,
                     seed=29042020)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
beta = sim.stan_variable('beta')
alpha = sim.stan_variable('alpha')
plt.plot(np.linspace(0,1000,1000), beta, linestyle='-')
plt.title('Beta')
plt.show()
plt.plot(np.linspace(0,1000,1000), alpha , linestyle = '-')
plt.title('Alpha')
plt.show()

# %%
height_columns = sim.draws_pd()
height_columns = height_columns.loc[:, 'height[1]':]

min_weights = []
max_weights = []
quant_5 = []
quant_25 = []
quant_50 = []
quant_75 = []
quant_95 = []


for column in height_columns:

    min_weights.append(min(height_columns[column]))
    max_weights.append(max(height_columns[column]))
    quant_5.append(height_columns[column].quantile(.05))
    quant_25.append(height_columns[column].quantile(.25))
    quant_50.append(height_columns[column].quantile(.5))
    quant_75.append(height_columns[column].quantile(.75))
    quant_95.append(height_columns[column].quantile(.95))

plt.plot(min_weights, label = 'min')
plt.plot(max_weights, label = 'max')
plt.plot(quant_5, label = 'quant_5')
plt.plot(quant_25, label = 'quant_25')
plt.plot(quant_50, label = 'quant_50')
plt.plot(quant_75, label = 'quant_75')
plt.plot(quant_95, label = 'quant_95')
plt.legend()

# %%
model_2_fit=CmdStanModel(stan_file=r'height_2_fit.stan')
# Out:
# INFO:cmdstanpy:compiling stan file C:\Users\macie\OneDrive\Pulpit\All\Studia\AIR_2022\Data_analytics\Data_Analytics\lab4\height_2_fit.stan to exe file C:\Users\macie\OneDrive\Pulpit\All\Studia\AIR_2022\Data_analytics\Data_Analytics\lab4\height_2_fit.exe
# INFO:cmdstanpy:compiled model executable: C:\Users\macie\OneDrive\Pulpit\All\Studia\AIR_2022\Data_analytics\Data_Analytics\lab4\height_2_fit.exe
# WARNING:cmdstanpy:Stan compiler has produced 2 warnings:
# WARNING:cmdstanpy:
# --- Translating Stan model to C++ code ---
# bin/stanc.exe  --o=C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2_fit.hpp C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2_fit.stan
# Warning in 'C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2_fit.stan', line 4, column 4: Declaration
#     of arrays by placing brackets after a variable name is deprecated and
#     will be removed in Stan 2.32.0. Instead use the array keyword before the
#     type. This can be changed automatically using the auto-format flag to
#     stanc
# Warning in 'C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2_fit.stan', line 25, column 3: Declaration
#     of arrays by placing brackets after a variable name is deprecated and
#     will be removed in Stan 2.32.0. Instead use the array keyword before the
#     type. This can be changed automatically using the auto-format flag to
#     stanc
#
# --- Compiling, linking C++ code ---
# g++ -std=c++1y -m64 -D_REENTRANT -Wall -Wno-unused-function -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-variable -Wno-sign-compare -Wno-unused-local-typedefs -Wno-int-in-bool-context -Wno-attributes -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.75.0 -I stan/lib/stan_math/lib/sundials_6.0.0/include -I stan/lib/stan_math/lib/sundials_6.0.0/src/sundials  -D_USE_MATH_DEFINES  -DBOOST_DISABLE_ASSERTS          -c  -x c++ -o C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2_fit.o C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2_fit.hpp
# g++ -std=c++1y -m64 -D_REENTRANT -Wall -Wno-unused-function -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-variable -Wno-sign-compare -Wno-unused-local-typedefs -Wno-int-in-bool-context -Wno-attributes -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.75.0 -I stan/lib/stan_math/lib/sundials_6.0.0/include -I stan/lib/stan_math/lib/sundials_6.0.0/src/sundials  -D_USE_MATH_DEFINES  -DBOOST_DISABLE_ASSERTS                -Wl,-L,"C:/Users/macie/anaconda3/envs/data/Library/bin/cmdstan/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"C:/Users/macie/anaconda3/envs/data/Library/bin/cmdstan/stan/lib/stan_math/lib/tbb"      C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2_fit.o src/cmdstan/main.o  -static-libgcc -static-libstdc++      -Wl,-L,"C:/Users/macie/anaconda3/envs/data/Library/bin/cmdstan/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"C:/Users/macie/anaconda3/envs/data/Library/bin/cmdstan/stan/lib/stan_math/lib/tbb"   stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_nvecserial.a stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_cvodes.a stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_idas.a stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_kinsol.a  stan/lib/stan_math/lib/tbb/tbb.dll -o C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2_fit.exe
# rm -f C:/Users/macie/OneDrive/Pulpit/All/Studia/AIR_2022/Data_analytics/Data_Analytics/lab4/height_2_fit.o

# %%
data_fit = {
    "N": 300,
    "weight": d["weight"][:300],
    "heights": d["height"][:300]
}

fit=model_2_fit.sample(data=data_fit,seed=28052020)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
#
#
# chain 1 |██▎       | 00:00 Iteration:  300 / 2000 [ 15%]  (Warmup)
#
# chain 1 |█████     | 00:00 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
# chain 1 |███████▋  | 00:00 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:00 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
beta = fit.stan_variable('beta')
alpha = fit.stan_variable('alpha')

plt.plot(beta)
plt.title('Sampled slope beta')
plt.show()
plt.plot(alpha)
plt.title('Intercept alpha')
plt.show()

# %%
height_columns = height_columns.loc[:, 'height[1]':]

min_weights = []
max_weights = []
quant_5 = []
quant_25 = []
quant_50 = []
quant_75 = []
quant_95 = []


for column in height_columns:

    min_weights.append(min(height_columns[column]))
    max_weights.append(max(height_columns[column]))
    quant_5.append(height_columns[column].quantile(.05))
    quant_25.append(height_columns[column].quantile(.25))
    quant_50.append(height_columns[column].quantile(.5))
    quant_75.append(height_columns[column].quantile(.75))
    quant_95.append(height_columns[column].quantile(.95))

plt.plot(min_weights, label = 'min')
plt.plot(max_weights, label = 'max')
plt.plot(quant_5, label = 'quant_5')
plt.plot(quant_25, label = 'quant_25')
plt.plot(quant_50, label = 'quant_50')
plt.plot(quant_75, label = 'quant_75')
plt.plot(quant_95, label = 'quant_95')
plt.legend()
